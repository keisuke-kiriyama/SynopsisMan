# %% [markdown]
# ## あらすじ文でもっとも長い文数

# %%
import os
from util.corpus_accessor import CorpusAccessor
import numpy as np

# %%
corpus_accessor = CorpusAccessor()

# %%
synopsises = [corpus_accessor.get_synopsis_lines(ncode) for ncode in corpus_accessor.ncodes]

# %%
synopsises[0]
# Out:
# ['日帰りで異世界に行ける沙耶。', '今度は新しい食材を求めて別の町に旅立つ？', 'お話。']

# %%
synopsis_lens = [len(synopsis) for synopsis in synopsises]

# %%
max(synopsis_lens)
# Out:
# 32

# %%
np.mean(synopsis_lens)
# Out:
# 4.369924812030075

# %%
synopsis_lens
# Out:
# [3,
#  1,
#  7,
#  7,
#  4,
#  2,
#  4,
#  11,
#  7,
#  1,
#  1,
#  6,
#  3,
#  3,
#  5,
#  2,
#  3,
#  4,
#  6,
#  5,
#  6,
#  3,
#  2,
#  6,
#  4,
#  1,
#  3,
#  4,
#  3,
#  1,
#  1,
#  1,
#  5,
#  1,
#  8,
#  6,
#  15,
#  5,
#  1,
#  10,
#  1,
#  1,
#  20,
#  4,
#  1,
#  1,
#  1,
#  1,
#  3,
#  3,
#  2,
#  4,
#  2,
#  1,
#  4,
#  4,
#  2,
#  2,
#  6,
#  3,
#  2,
#  3,
#  4,
#  4,
#  5,
#  7,
#  4,
#  7,
#  1,
#  1,
#  6,
#  12,
#  6,
#  19,
#  5,
#  19,
#  8,
#  7,
#  11,
#  2,
#  4,
#  11,
#  17,
#  2,
#  2,
#  3,
#  1,
#  2,
#  6,
#  4,
#  4,
#  6,
#  1,
#  8,
#  3,
#  2,
#  4,
#  1,
#  3,
#  2,
#  1,
#  7,
#  1,
#  7,
#  4,
#  2,
#  4,
#  4,
#  2,
#  3,
#  2,
#  4,
#  4,
#  3,
#  4,
#  10,
#  8,
#  4,
#  5,
#  2,
#  6,
#  15,
#  1,
#  2,
#  4,
#  3,
#  2,
#  6,
#  5,
#  1,
#  7,
#  7,
#  2,
#  6,
#  0,
#  7,
#  5,
#  4,
#  1,
#  3,
#  3,
#  3,
#  10,
#  1,
#  5,
#  3,
#  2,
#  6,
#  9,
#  2,
#  1,
#  5,
#  5,
#  1,
#  4,
#  3,
#  2,
#  1,
#  6,
#  4,
#  8,
#  4,
#  1,
#  5,
# ...
